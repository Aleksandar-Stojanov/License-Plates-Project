# %%
# !pip install easyocr
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# !pip install imutils
# Out:
# Requirement already satisfied: easyocr in /usr/local/lib/python3.10/dist-packages (1.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from easyocr) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.16.0+cu121)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from easyocr) (4.8.1.78)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.11.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from easyocr) (9.4.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.19.3)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from easyocr) (2.0.2)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (2.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->easyocr) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5->easyocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5->easyocr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5->easyocr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5->easyocr) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->easyocr) (1.3.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Requirement already satisfied: imutils in /usr/local/lib/python3.10/dist-packages (0.5.4)

# %%
import pytesseract
import matplotlib.pyplot as plt
import cv2
import glob
import os
import easyocr
import numpy as np
import imutils
from difflib import SequenceMatcher

# %%
def process_image(input_path, output_path):
    img = cv2.imread(input_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    bfilter = cv2.bilateralFilter(gray, 11, 17, 17)
    edged = cv2.Canny(bfilter, 30, 200)
    keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(keypoints)
    contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

    location = None
    for contour in contours:
        approx = cv2.approxPolyDP(contour, 10, True)
        if len(approx) == 4:
            x, y, w, h = cv2.boundingRect(contour)
            roi = img[y:y + h, x:x + w]

            text = pytesseract.image_to_string(roi, lang='eng', config='--oem 3 --psm 6 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789')

            if text and len(text) > 4:
                location = approx
                break


    mask = np.zeros(gray.shape, np.uint8)

    if location is not None:
        new_image = cv2.drawContours(mask, [location], 0, 255, -1)
        new_image = cv2.bitwise_and(img, img, mask=mask)
        (x, y) = np.where(mask == 255)
        (x1, y1) = (np.min(x), np.min(y))
        (x2, y2) = (np.max(x), np.max(y))
        cropped_image = gray[x1:x2 + 1, y1:y2 + 1]

        if cropped_image.size != 0:
            filename = os.path.basename(input_path)
            output_file = os.path.join(output_path, filename)
            cv2.imwrite(output_file, cropped_image)
            print(f"Processed and saved: {output_file}")
        else:
            print("Cropped image is empty.")
    else:
        print("No license plate found in:", input_path)

# %%
def calculate_predicted_similarity(actual_list, predicted_list):
    similarities = []

    for actual_plate, predict_plate in zip(actual_list, predicted_list):
        similarity_ratio = SequenceMatcher(None, actual_plate, predict_plate).ratio()
        similarities.append(similarity_ratio)

    return similarities

# %%
def calculate_cumulative_similarity(actual_list, predicted_list):
    total_similarity = 0

    for actual_plate, predict_plate in zip(actual_list, predicted_list):
        similarity_ratio = SequenceMatcher(None, actual_plate, predict_plate).ratio()
        total_similarity += similarity_ratio

    average_similarity = total_similarity / len(actual_list)

    return average_similarity

# %%
input_folder = '/content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images'
output_folder = '/content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images'

os.makedirs(output_folder, exist_ok=True)

for path_to_license_plate in os.listdir(input_folder):
    if path_to_license_plate.endswith('.jpg'):
        input_path = os.path.join(input_folder, path_to_license_plate)
        process_image(input_path, output_folder)
path_for_license_plates = r"/content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/*.jpg"

best_psm_value = 0;
best_accuracy = 0;
for i in range(6,14):
  list_license_plates = []
  predicted_license_plates = []
  for path_to_license_plate in glob.glob(path_for_license_plates, recursive=True):

      license_plate_file = path_to_license_plate.split("/")[-1]
      license_plate, _ = os.path.splitext(license_plate_file)

      list_license_plates.append(license_plate)


      img = cv2.imread(path_to_license_plate)

      predicted_result = pytesseract.image_to_string(img, lang='eng', config=f'--oem 3 --psm {i} -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789')
      filter_predicted_result = "".join(predicted_result.split()).replace(":", "").replace("-", "")
      predicted_license_plates.append(filter_predicted_result)
      average_similarity = calculate_cumulative_similarity(list_license_plates, predicted_license_plates)
  if best_accuracy < average_similarity:
    best_prediction=[]
    best_psm_value = i
    best_accuracy = average_similarity
    best_prediction = [i for i in predicted_license_plates]
# Out:
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK9889AM.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK5956AU.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/VE2376AD.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/OH6549AD.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/PP0001DD.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK9435BF.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/BT7268AE.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/VE2065AC.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK0685BE.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/TE5420AF.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK2772BJ.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK1132AO.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/BT9386AE.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/RA7112AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/BT3618AC.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/BT0315AG.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/GV0001SB.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/KS1962AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/TE3719AI.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK8460AG.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/PP5103AF.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/GV4643AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/PP1658AF.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/PP7777EV.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/PP2323AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/PP1999AC.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK5342BG.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK393VA.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK5294BE.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/BT4130AD.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/BT7855AC.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/PP0118AF.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/GV0533AE.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK619VD.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK898VK.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK3616AC.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/BT7649AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK694OF.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/KU5604AD.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SU1440AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK1999BB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK2466BA.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK598TE.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK2988AK.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK3824AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK3016BA.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK6123AR.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/GV0001AO.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK2043AL.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK8854AM.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/KU0522AE.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK988MV.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK1705BD.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK006NM.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK0049BA.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK7534AZ.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/TE4500AE.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK5481AF.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK9411AG.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SR3334AE.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SR5552AE.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK802SS.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK9748BB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK2037AR.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/PP5853AE.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/TE0001SR.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK8838AP.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/BT9599AD.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/GV5000AO.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/BT9922AD.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/ST9169AD.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK955SU.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/BT3754AG.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/VE111CB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK1745BC.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK7457AM.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK909FO.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK3554BK.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/BT968AI.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SU3440AD.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK5559BG.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK5843BF.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/GE0810AC.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK300SO.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK262NV.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK3320AR.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/PS8000AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK908RO.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/PP8103AC.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK1245BE.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/TE4473AJ.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/OH622AM.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/VE992RD.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/KU2007AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK5877AP.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK079VM.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/OH611BS.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/BT0284AB.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK3570AR.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/KA2505AC.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK0771BI.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/SK0135BK.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/TE7777JM.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK0108AV.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK7665BC.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK3864AN.jpg
# No license plate found in: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/downloaded_images/SK3071AZ.jpg
# Processed and saved: /content/drive/MyDrive/Colab Notebooks/LicensePlatesProject/processed_images/PP0801AG.jpg

# %%
similarities = calculate_predicted_similarity(list_license_plates, best_prediction)
for actual_plate, predict_plate, similarity in zip(list_license_plates, best_prediction, similarities):
    print(f"Actual: {actual_plate}\tPredicted: {predict_plate}\tSimilarity: {similarity:.2f}")

average_similarity = calculate_cumulative_similarity(list_license_plates, best_prediction)

print(f"Average Similarity: {average_similarity:.2%}")
# Out:
# Actual: SK9889AM	Predicted: SK9889AN	Similarity: 0.88
# Actual: VE2376AD	Predicted: BVE2376AD	Similarity: 0.94
# Actual: PP0001DD	Predicted: PP00010D	Similarity: 0.88
# Actual: TE5420AF	Predicted: WEE5220009	Similarity: 0.44
# Actual: SK2772BJ	Predicted: SK2722B8J	Similarity: 0.82
# Actual: RA7112AB	Predicted: PRA112A8	Similarity: 0.75
# Actual: BT0315AG	Predicted: B0	Similarity: 0.40
# Actual: KS1962AB	Predicted: BS81962AB	Similarity: 0.82
# Actual: SK8460AG	Predicted: SK88460AG	Similarity: 0.94
# Actual: SK5342BG	Predicted: SK25342B6	Similarity: 0.82
# Actual: SK5294BE	Predicted: SK55294BEI	Similarity: 0.89
# Actual: BT7855AC	Predicted: BT27855AC	Similarity: 0.94
# Actual: SK619VD	Predicted: SK619VD	Similarity: 1.00
# Actual: BT7649AB	Predicted: T7EZSAB	Similarity: 0.53
# Actual: KU5604AD	Predicted: KUB5602AN	Similarity: 0.71
# Actual: SK2988AK	Predicted: MK2900A	Similarity: 0.53
# Actual: SK3824AB	Predicted: ROTLAB	Similarity: 0.29
# Actual: SK6123AR	Predicted: BSK6123AP	Similarity: 0.82
# Actual: GV0001AO	Predicted: V000TTO	Similarity: 0.67
# Actual: SK2043AL	Predicted: ISK82023AL	Similarity: 0.78
# Actual: SK1705BD	Predicted: SK1705BD	Similarity: 1.00
# Actual: SK006NM	Predicted: SK2006N	Similarity: 0.86
# Actual: SK0049BA	Predicted: SK004958	Similarity: 0.75
# Actual: SK5481AF	Predicted: SK95481AF	Similarity: 0.94
# Actual: SR5552AE	Predicted: SR5552AE	Similarity: 1.00
# Actual: ST9169AD	Predicted: BT9	Similarity: 0.36
# Actual: SK955SU	Predicted: SK2955SU	Similarity: 0.93
# Actual: SK262NV	Predicted: S267NV	Similarity: 0.77
# Actual: PS8000AB	Predicted: IEPS8000A8J	Similarity: 0.74
# Actual: PP8103AC	Predicted: T	Similarity: 0.00
# Actual: SK1245BE	Predicted: YE1	Similarity: 0.18
# Actual: OH611BS	Predicted: OH611BS	Similarity: 1.00
# Actual: BT0284AB	Predicted: T028A8	Similarity: 0.71
# Actual: SK0135BK	Predicted: KSU1S9BK	Similarity: 0.50
# Actual: PP0801AG	Predicted: PP20801AG	Similarity: 0.94
# Average Similarity: 72.98%
